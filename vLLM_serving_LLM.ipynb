# %%
# !pip install vllm
# !pip install -U "huggingface_hub[cli]"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.2/377.2 MB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.3/100.3 kB 8.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.0/111.0 kB 10.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 75.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.6/87.6 kB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 865.2/865.2 MB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 94.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 109.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.5/31.5 MB 66.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 115.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 62.1 MB/s eta 0:00:00
# ...

# %%
# !nohup vllm serve google/gemma-2-2b-it --dtype auto --api-key token-abc123 &
# Out:
# nohup: appending output to 'nohup.out'

# %%
# !pip install openai

# %%
from openai import OpenAI

client = OpenAI(
    base_url="http://localhost:8000/v1",
    api_key="token-abc123",
)



completion = client.chat.completions.create(
  model="google/gemma-2-2b-it",
  messages=[
    {"role": "user", "content": "write a function with python to calculation sin(x)"}
  ]
)

print(completion.choices[0].message.content)
# Out:
# ```python
# import math
#
# def sin(x):
#   """Calculates the sine of a given angle in radians.
#
#   Args:
#     x: The angle in radians.
#
#   Returns:
#     The sine of the angle, or None if the input is not valid.
#   """
#   if isinstance(x, (int, float)) and x >= 0:
#     return math.sin(x)
#   else:
#     print("Invalid input. Angle must be a non-negative number in radians.")
#     return None
#
# # Example usage
# angle_radians = math.pi / 2
# sine_value = sin(angle_radians)
# print(f"The sine of {angle_radians} radians is: {sine_value}")
# ```
#
# **Explanation:**
#
# 1. **Import `math` module:**
#    - This line brings in the Python library for mathematical functions, including `math.sin()`
#
# 2. **`sin(x)` function definition:**
#    - This defines a function named `sin` that accepts a single argument `x`, representing the angle in radians.
#
# 3. **Input validation:**
# ...

# %%
pip install langchain-openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.2/65.2 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.1/438.1 kB 17.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.0/363.0 kB 32.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langsmith
#     Found existing installation: langsmith 0.3.44
#     Uninstalling langsmith-0.3.44:
#       Successfully uninstalled langsmith-0.3.44
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.63
#     Uninstalling langchain-core-0.3.63:
#       Successfully uninstalled langchain-core-0.3.63
# ...

# %%
from langchain_openai import ChatOpenAI
base_url="http://localhost:8000/v1",
api_key="token-abc123",
model_name = "google/gemma-2-2b-it"
llm = ChatOpenAI(
    base_url='http://localhost:8000/v1',
    model='google/gemma-2-2b-it',
    api_key='token-abc123',
)

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.messages import HumanMessage

prompt = ChatPromptTemplate.from_messages([
    MessagesPlaceholder(variable_name="chat_history"),
    HumanMessage(content="{input}")  # فقط نقش user
])

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

# مدل LLM
llm = ChatOpenAI(
    base_url="http://localhost:8000/v1",
    model="google/gemma-2-2b-it",
    api_key="token-abc123"
)

# پیام قالب (فقط human message)
prompt = ChatPromptTemplate.from_messages([
    ("human", "{input}")
])

# اتصال قالب به مدل
chain = prompt | llm

# فراخوانی مدل
response = chain.invoke({"input": "در مورد سعدی یک پاراگراف به فارسی بنویس"})
print(response.content)
# Out:
# سعدی، ی此外 هنرمند و شاعر نامدار فارسی‌زبان، در محله می‌کند  ش عرفان  نویسیات و سیاسی‌اش را به تأثیرپذیرترین آثار خود تبدیل کرد. با داستانی  منوط با نظم و فصاحت، زندگی‌اش  در خ청فACION перемен  و بکارگیری د privé مvention  کشف می‌کنیم. او مجموعه‌ای ازความจริง về فردی، عمیق و فلسفی از. و راه‌های خود را با نظم و art   сочетаний "zamee الح primas  و از لحاظ نظری، انقلابیانه و تحلیلی بود.
